# %%
import numpy as np
a = np.empty((2,3))
print a
# Out:
# [[  1.96345956e-316   1.96345838e-316   2.50026224e-315]
#  [  3.60171524e-316   1.96345719e-316   1.96345601e-316]]

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
a = [1,2,3,4,5,6]
n = np.array(a)
a[2:5]
# Out:
# [3, 4, 5]

# %%
iris=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
type(iris)
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns
# Out:
# Index([u'5.1', u'3.5', u'1.4', u'0.2', u'Iris-setosa'], dtype='object')

# %%
iris.columns = ['sl','sw','pl','pw','flower-class']
iris.head()
# Out:
#     sl   sw   pl   pw flower-class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.dtypes
# Out:
# sl              float64
# sw              float64
# pl              float64
# pw              float64
# flower-class     object
# dtype: object

# %%
iris.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
pd.isnull(iris)
# Out:
#         sl     sw     pl     pw flower-class
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# 5    False  False  False  False        False
# 6    False  False  False  False        False
# 7    False  False  False  False        False
# 8    False  False  False  False        False
# 9    False  False  False  False        False
# 10   False  False  False  False        False
# 11   False  False  False  False        False
# 12   False  False  False  False        False
# 13   False  False  False  False        False
# 14   False  False  False  False        False
# 15   False  False  False  False        False
# 16   False  False  False  False        False
# 17   False  False  False  False        False
# 18   False  False  False  False        False
# 19   False  False  False  False        False
# ...

# %%
pd.isnull(iris).sum()
# Out:
# sl              0
# sw              0
# pl              0
# pw              0
# flower-class    0
# dtype: int64

# %%
iris.iloc[1:3,1:2]
# Out:
#     sw
# 1  3.2
# 2  3.1

# %%
iris.iloc[1:3 ,1:2]=np.nan
iris.head()
# Out:
#     sl   sw   pl   pw flower-class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  NaN  1.3  0.2  Iris-setosa
# 2  4.6  NaN  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
pd.isnull(iris)
# Out:
#         sl     sw     pl     pw flower-class
# 0    False  False  False  False        False
# 1    False   True  False  False        False
# 2    False   True  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# 5    False  False  False  False        False
# 6    False  False  False  False        False
# 7    False  False  False  False        False
# 8    False  False  False  False        False
# 9    False  False  False  False        False
# 10   False  False  False  False        False
# 11   False  False  False  False        False
# 12   False  False  False  False        False
# 13   False  False  False  False        False
# 14   False  False  False  False        False
# 15   False  False  False  False        False
# 16   False  False  False  False        False
# 17   False  False  False  False        False
# 18   False  False  False  False        False
# 19   False  False  False  False        False
# ...

# %%
#make changes to the NaN valus
iris.sw.fillna(1,inplace=True)

# %%
iris.head()
# Out:
#     sl   sw   pl   pw flower-class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  1.0  1.3  0.2  Iris-setosa
# 2  4.6  1.0  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# or replace NaN values with mean of the column
iris.sw.fillna(iris.sw.mean(),inplace=True)

# %%
#output Y and input X
Y=iris['flower-class']
Y
del iris['flower-class']
print(Y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# ...

# %%
iris.head()
# Out:
#     sl   sw   pl   pw
# 0  4.9  3.0  1.4  0.2
# 1  4.7  1.0  1.3  0.2
# 2  4.6  1.0  1.5  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4

# %%
iris.iloc[1:3,:]=np.nan
iris.head()
iris.dropna(inplace=True)
iris.head()
# Out:
#     sl   sw   pl   pw
# 0  4.9  3.0  1.4  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4
# 5  4.6  3.4  1.4  0.3
# 6  5.0  3.4  1.5  0.2

# %%
iris.reset_index()
a=iris.reset_index()
a
# Out:
#      index   sl   sw   pl   pw
# 0        0  4.9  3.0  1.4  0.2
# 1        3  5.0  3.6  1.4  0.2
# 2        4  5.4  3.9  1.7  0.4
# 3        5  4.6  3.4  1.4  0.3
# 4        6  5.0  3.4  1.5  0.2
# 5        7  4.4  2.9  1.4  0.2
# 6        8  4.9  3.1  1.5  0.1
# 7        9  5.4  3.7  1.5  0.2
# 8       10  4.8  3.4  1.6  0.2
# 9       11  4.8  3.0  1.4  0.1
# 10      12  4.3  3.0  1.1  0.1
# 11      13  5.8  4.0  1.2  0.2
# 12      14  5.7  4.4  1.5  0.4
# 13      15  5.4  3.9  1.3  0.4
# 14      16  5.1  3.5  1.4  0.3
# 15      17  5.7  3.8  1.7  0.3
# 16      18  5.1  3.8  1.5  0.3
# 17      19  5.4  3.4  1.7  0.2
# 18      20  5.1  3.7  1.5  0.4
# 19      21  4.6  3.6  1.0  0.2
# 20      22  5.1  3.3  1.7  0.5
# 21      23  4.8  3.4  1.9  0.2
# 22      24  5.0  3.0  1.6  0.2
# 23      25  5.0  3.4  1.6  0.4
# 24      26  5.2  3.5  1.5  0.2
# 25      27  5.2  3.4  1.4  0.2
# 26      28  4.7  3.2  1.6  0.2
# 27      29  4.8  3.1  1.6  0.2
# 28      30  5.4  3.4  1.5  0.4
# ...

# %%
iris.reset_index(drop=True,inplace=True)
iris
# Out:
#       sl   sw   pl   pw
# 0    4.9  3.0  1.4  0.2
# 1    5.0  3.6  1.4  0.2
# 2    5.4  3.9  1.7  0.4
# 3    4.6  3.4  1.4  0.3
# 4    5.0  3.4  1.5  0.2
# 5    4.4  2.9  1.4  0.2
# 6    4.9  3.1  1.5  0.1
# 7    5.4  3.7  1.5  0.2
# 8    4.8  3.4  1.6  0.2
# 9    4.8  3.0  1.4  0.1
# 10   4.3  3.0  1.1  0.1
# 11   5.8  4.0  1.2  0.2
# 12   5.7  4.4  1.5  0.4
# 13   5.4  3.9  1.3  0.4
# 14   5.1  3.5  1.4  0.3
# 15   5.7  3.8  1.7  0.3
# 16   5.1  3.8  1.5  0.3
# 17   5.4  3.4  1.7  0.2
# 18   5.1  3.7  1.5  0.4
# 19   4.6  3.6  1.0  0.2
# 20   5.1  3.3  1.7  0.5
# 21   4.8  3.4  1.9  0.2
# 22   5.0  3.0  1.6  0.2
# 23   5.0  3.4  1.6  0.4
# 24   5.2  3.5  1.5  0.2
# 25   5.2  3.4  1.4  0.2
# 26   4.7  3.2  1.6  0.2
# 27   4.8  3.1  1.6  0.2
# 28   5.4  3.4  1.5  0.4
# 29   5.2  4.1  1.5  0.1
# ..   ...  ...  ...  ...
# 117  6.9  3.2  5.7  2.3
# 118  5.6  2.8  4.9  2.0
# 119  7.7  2.8  6.7  2.0
# 120  6.3  2.7  4.9  1.8
# 121  6.7  3.3  5.7  2.1
# 122  7.2  3.2  6.0  1.8
# ...

# %%
iris
# Out:
#       sl   sw   pl   pw
# 0    4.9  3.0  1.4  0.2
# 1    5.0  3.6  1.4  0.2
# 2    5.4  3.9  1.7  0.4
# 3    4.6  3.4  1.4  0.3
# 4    5.0  3.4  1.5  0.2
# 5    4.4  2.9  1.4  0.2
# 6    4.9  3.1  1.5  0.1
# 7    5.4  3.7  1.5  0.2
# 8    4.8  3.4  1.6  0.2
# 9    4.8  3.0  1.4  0.1
# 10   4.3  3.0  1.1  0.1
# 11   5.8  4.0  1.2  0.2
# 12   5.7  4.4  1.5  0.4
# 13   5.4  3.9  1.3  0.4
# 14   5.1  3.5  1.4  0.3
# 15   5.7  3.8  1.7  0.3
# 16   5.1  3.8  1.5  0.3
# 17   5.4  3.4  1.7  0.2
# 18   5.1  3.7  1.5  0.4
# 19   4.6  3.6  1.0  0.2
# 20   5.1  3.3  1.7  0.5
# 21   4.8  3.4  1.9  0.2
# 22   5.0  3.0  1.6  0.2
# 23   5.0  3.4  1.6  0.4
# 24   5.2  3.5  1.5  0.2
# 25   5.2  3.4  1.4  0.2
# 26   4.7  3.2  1.6  0.2
# 27   4.8  3.1  1.6  0.2
# 28   5.4  3.4  1.5  0.4
# 29   5.2  4.1  1.5  0.1
# ..   ...  ...  ...  ...
# 117  6.9  3.2  5.7  2.3
# 118  5.6  2.8  4.9  2.0
# 119  7.7  2.8  6.7  2.0
# 120  6.3  2.7  4.9  1.8
# 121  6.7  3.3  5.7  2.1
# 122  7.2  3.2  6.0  1.8
# ...

# %%
print iris.groupby('sw').size()
# Out:
# sw
# 2.0     1
# 2.2     3
# 2.3     4
# 2.4     3
# 2.5     8
# 2.6     5
# 2.7     9
# 2.8    14
# 2.9    10
# 3.0    26
# 3.1    11
# 3.2    12
# 3.3     6
# 3.4    12
# 3.5     5
# 3.6     3
# 3.7     3
# 3.8     6
# 3.9     2
# 4.0     1
# 4.1     1
# 4.2     1
# 4.4     1
# dtype: int64
